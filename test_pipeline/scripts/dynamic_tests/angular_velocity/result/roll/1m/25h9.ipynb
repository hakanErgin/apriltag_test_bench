# %%
import rosbag
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import tf
import seaborn as sns

# %%
bag = rosbag.Bag('/home/uware/rosbags/dynamic/rotational/roll/1m/25h9.bag')

# create variables
target = 'is_detected'

# we are interested if tag is detected at 90°/s

# %%
topic = '/tag_detections'

rows = []
false_positives = []

# z distance to make sure its not fp
range = (.9, 1.1)

for topic, msg, t in bag.read_messages(topics=topic):
    time = t
    is_detected = len(msg.detections)

    if is_detected==1:
        position = msg.detections[0].pose.pose.pose.position
        if range[0] < position.z < range[1]:
            orientation_quat = msg.detections[0].pose.pose.pose.orientation
            pitch, yaw, roll = tf.transformations.euler_from_quaternion([orientation_quat.x,orientation_quat.y,orientation_quat.z,orientation_quat.w], axes='rxyz')
            row={'time': time.to_sec(), target: is_detected, 'roll': np.degrees(roll), 'distance': position.z}
        else:
            false_positives.append(msg.detections[0])

    elif is_detected>1:
        for detection in msg.detections:
            position = detection.pose.pose.pose.position
            if range[0] < position.z < range[1]:
                orientation_quat = detection.pose.pose.pose.orientation
                pitch, yaw, roll = tf.transformations.euler_from_quaternion([orientation_quat.x,orientation_quat.y,orientation_quat.z,orientation_quat.w], axes='rxyz')
                row={'time': time.to_sec(), target: 1, 'roll': np.degrees(roll), 'distance': position.z}
            else:
                false_positives.append(detection)
                
    elif is_detected==0:
        row={'time': time.to_sec(), target: is_detected, 'roll': None}
    rows.append(row)

df = pd.DataFrame.from_records(rows)
print(len(false_positives))
# Out:
# 0

# %%
# calculate relative time in seconds instead of absolute time
df['relative_time'] =  df.loc[0:, 'time'] - df.at[0, 'time']
df = df.drop(columns=['time'])
df.groupby(target).head(2)
# Out:
#    is_detected        roll  distance  relative_time
# 0            1  124.771825  1.064877       0.000000
# 1            1   80.692779  1.065899       1.025313

# %%
df.roll.describe()
# Out:
# count    184.000000
# mean      89.455207
# std       26.602442
# min       50.987415
# 25%       65.689795
# 50%       89.079142
# 75%      111.349310
# max      130.489272
# Name: roll, dtype: float64

# %%
df.roll.max() - df.roll.min()
# Out:
# 79.50185737774189

# %%
# show all
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df)
# Out:
#      is_detected        roll  distance  relative_time
# 0              1  124.771825  1.064877       0.000000
# 1              1   80.692779  1.065899       1.025313
# 2              1  130.489272  1.066656       1.787578
# 3              1  102.747328  1.063625       2.603549
# 4              1  129.275680  1.063787       3.825982
# 5              1  106.865847  1.065950       4.355354
# 6              1   93.565216  1.062108       5.142555
# 7              1   60.652482  1.068351       5.854117
# 8              1  119.986713  1.065950       6.473633
# 9              1   93.669329  1.065521       7.323376
# 10             1   60.797512  1.069454       7.833908
# 11             1   51.098043  1.070828       8.390036
# 12             1  130.438680  1.064653       8.862021
# 13             1  115.634917  1.067274       9.504307
# 14             1   93.402531  1.065356       9.979580
# 144            1   80.735496  1.066162      51.166667
# 145            1   51.147898  1.070396      51.509386
# 146            1  110.810471  1.065959      51.817650
# 147            1   89.274845  1.066263      52.111505
# 148            1   60.797512  1.069454      52.290039
# 149            1   51.098043  1.070828      52.494987
# 150            1   51.098043  1.070828      52.819393
# 151            1  111.349310  1.064104      53.165988
# 152            1   80.692779  1.065899      53.467911
# 153            1   50.987415  1.071299      53.778486
# 154            1  115.627166  1.065077      54.086807
# 155            1   93.828580  1.065455      54.396338
# 156            1   65.775681  1.068125      54.693393
# 157            1  120.223601  1.068069      55.068815
# 158            1   88.983903  1.065844      55.333967
# 159            1   70.647556  1.067921      55.642118
# 160            1  129.318496  1.065705      55.934156
# 161            1  102.157562  1.066375      56.288875
# 162            1   75.293412  1.066165      56.530049
# 163            1   51.098043  1.070828      56.816905
# 164            1  130.438680  1.064653      57.098169
# 165            1  115.668577  1.067250      57.412500
# 166            1   89.079142  1.067883      57.794283
# 167            1   56.067786  1.071780      58.124032
# 168            1  106.577706  1.067143      58.500375
# 169            1   80.176185  1.065790      58.835775
# 170            1   51.050380  1.071816      59.190656
# 171            1  102.825135  1.062706      59.522442
# 172            1   75.290931  1.067131      59.855860
# 173            1  130.449804  1.064875      60.126219
# 174            1  106.779325  1.065278      60.463529
# 175            1   84.641836  1.064731      60.699743
# 176            1   65.931689  1.069135      60.901805
# 177            1   51.098043  1.070828      61.122962
# 178            1   51.098043  1.070828      61.460180
# 179            1  106.749790  1.066518      61.768162
# 180            1   84.964399  1.066582      62.045311
# 181            1   56.067786  1.071780      62.423037
# 182            1  110.752551  1.067239      62.748679
# 183            1   80.176185  1.065790      63.172307

# %%
# ratio of detected to not
ratios = df.is_detected.value_counts(normalize=True)*100
ratios
# Out:
# 1    100.0
# Name: is_detected, dtype: float64

# %%
ratios.plot.pie()
plt.legend()

# %%
df.head(5)
# Out:
#    is_detected        roll  distance  relative_time
# 0            1  124.771825  1.064877       0.000000
# 1            1   80.692779  1.065899       1.025313
# 2            1  130.489272  1.066656       1.787578
# 3            1  102.747328  1.063625       2.603549
# 4            1  129.275680  1.063787       3.825982

# %%
df.plot.hexbin(x=target, y="relative_time", gridsize=15)
sns.catplot(x=target, y='relative_time', data=df)
sns.catplot(x=target, y='relative_time', data=df, kind="swarm", s=4) # s=size of markers causes warnings when >4

# creating a dummy column for plotting both classes together
df.loc[:,'all'] = 'all'
sns.catplot(x='all', y='relative_time', data=df, hue=target, kind="swarm")

# %%
df.roll.describe()
# Out:
# count    184.000000
# mean      89.455207
# std       26.602442
# min       50.987415
# 25%       65.689795
# 50%       89.079142
# 75%      111.349310
# max      130.489272
# Name: roll, dtype: float64
